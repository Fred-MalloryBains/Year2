# %%
import numpy as np

import math
import matplotlib.pyplot as plt

# %%
a = []
a.append(1/math.sqrt(3))
function(a,a[len(a)-1])
get_table(a)
# Out:
# [0.5773502691896258]
# [0.5773502691896258, 0.2679491924311229]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472, 0.016363922135311803]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472, 0.016363922135311803, 0.00818141340378924]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472, 0.016363922135311803, 0.00818141340378924, 0.004090638250780627]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472, 0.016363922135311803, 0.00818141340378924, 0.004090638250780627, 0.0020453105692209224]
# [0.5773502691896258, 0.2679491924311229, 0.13165249758739625, 0.06554346281523889, 0.03273661041297472, 0.016363922135311803, 0.00818141340378924, 0.004090638250780627, 0.0020453105692209224, 0.0010226542151096536]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 4
#       2 a.append(1/math.sqrt(3))
#       3 function(a,a[len(a)-1])
# ----> 4 get_table(a)
#
# Cell In[38], line 18, in get_table(a)
#      15 ax.yaxis.set_visible(False)
#      16 ax.set_frame_on(False)
# ---> 18 plt.subplots_adjust(left=0.9, bottom=0.9)
#      19 plt.show()
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/pyplot.py:2781, in subplots_adjust(left, bottom, right, top, wspace, hspace)
#    2772 @_copy_docstring_and_deprecators(Figure.subplots_adjust)
#    2773 def subplots_adjust(
#    2774     left: float | None = None,
#    (...)
#    2779     hspace: float | None = None,
#    2780 ) -> None:
# -> 2781     gcf().subplots_adjust(
#    2782         left=left, bottom=bottom, right=right, top=top, wspace=wspace, hspace=hspace
#    2783     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/figure.py:1294, in FigureBase.subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    1289     _api.warn_external(
#    1290         "This figure was using a layout engine that is "
#    1291         "incompatible with subplots_adjust and/or tight_layout; "
#    1292         "not calling subplots_adjust.")
#    1293     return
# -> 1294 self.subplotpars.update(left, bottom, right, top, wspace, hspace)
#    1295 for ax in self.axes:
#    1296     if ax.get_subplotspec() is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/matplotlib/gridspec.py:773, in SubplotParams.update(self, left, bottom, right, top, wspace, hspace)
#     768 """
#     769 Update the dimensions of the passed parameters. *None* means unchanged.
#     770 """
#     771 if ((left if left is not None else self.left)
#     772         >= (right if right is not None else self.right)):
# --> 773     raise ValueError('left cannot be >= right')
#     774 if ((bottom if bottom is not None else self.bottom)
#     775         >= (top if top is not None else self.top)):
#     776     raise ValueError('bottom cannot be >= top')
#
# ValueError: left cannot be >= right

# %%
def absolute (num,pos):
    value1 = num * 2 ** pos * 6
    value2 = abs(value1 - math.pi)
    value3 = value2 / math.pi

# %%
def function (a, num):
    print (a)
    while (len(a) < 10):
        new = ((math.sqrt(num **2 + 1 )-1)/num)
        a.append(new)
        absolute(new,len(a)-1)
        function(a,a[len(a)-1])

# %%
def new_function (a,num):
    while (len(a) < 200):
        new = (num / (math.sqrt(num**2 + 1) + 1))
        a.append(new)
        absolute(new,len(a)-1)
        new_function(a,a[len(a)-1])

# %%
def get_table (a):
    
    fig, ax = plt.subplots()
    iterations = np.arange(len(a)) 
    cell_text = [[i, value] for i, value in zip(iterations, a)]  
    

    columns = ("Iteration", "Formula Value")
    the_table = plt.table(cellText=cell_text,
                          colLabels=columns,
                          cellLoc='center',
                          loc='center')

    ax.xaxis.set_visible(False)
    ax.yaxis.set_visible(False)
    ax.set_frame_on(False)
    
    plt.subplots_adjust(left=0.2, bottom=0.3)
    plt.show()
